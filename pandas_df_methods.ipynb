# %%
import numpy as np
import pandas as pd

# %%
marks = pd.DataFrame([
    [100,80,10],
    [90 ,70,7],
    [120 ,100,14],
    [80,70,14],
    [80,70,14]
],columns=['iq' , 'marks' , 'package'])

# %%
marks
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     70       14
# 4   80     70       14

# %%
#value_counts -> series and df
marks.value_counts()# gives a row frequency count and to much useful in the practise
# Out:
# iq   marks  package
# 80   70     14         2
# 90   70     7          1
# 100  80     10         1
# 120  100    14         1
# Name: count, dtype: int64

# %%
df = pd.read_csv("IPL Matches 2008-2020.csv")

# %%
df.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
#shape
df.shape
# Out:
# (816, 17)

# %%
#dtypes
df.dtypes
# Out:
# id                   int64
# city                object
# date                object
# player_of_match     object
# venue               object
# neutral_venue        int64
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# winner              object
# result              object
# result_margin      float64
# eliminator          object
# method              object
# umpire1             object
# umpire2             object
# dtype: object

# %%
# fetching index
df.index
# Out:
# RangeIndex(start=0, stop=816, step=1)

# %%
# fetching colums 
df.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
#values in 2d numpy array
df.values
# Out:
# array([[335982, 'Bangalore', '2008-04-18', ..., nan, 'Asad Rauf',
#         'RE Koertzen'],
#        [335983, 'Chandigarh', '2008-04-19', ..., nan, 'MR Benson',
#         'SL Shastri'],
#        [335984, 'Delhi', '2008-04-19', ..., nan, 'Aleem Dar',
#         'GA Pratapkumar'],
#        ...,
#        [1237178, 'Abu Dhabi', '2020-11-06', ..., nan, 'PR Reiffel',
#         'S Ravi'],
#        [1237180, 'Abu Dhabi', '2020-11-08', ..., nan, 'PR Reiffel',
#         'S Ravi'],
#        [1237181, 'Dubai', '2020-11-10', ..., nan, 'CB Gaffaney',
#         'Nitin Menon']], dtype=object)

# %%
df.isnull().sum()#very useful
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
#duplicated 
df.duplicated().sum()
# Out:
# 0

# %%
marks.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
marks.duplicated().sum()
# Out:
# 1

# %%
#rename
marks.rename(columns={'package' : 'lpa'},inplace=True)

# %%
marks
# Out:
#     iq  marks  lpa
# 0  100     80   10
# 1   90     70    7
# 2  120    100   14
# 3   80     70   14
# 4   80     70   14

# %% [markdown]
# ### Math Methods

# %%
#sum -> axis argument
marks.sum(axis=1)
# Out:
# 0    190
# 1    167
# 2    234
# 3    164
# 4    164
# dtype: int64

# %%
marks.mean(axis = 0)
# Out:
# iq       94.0
# marks    78.0
# lpa      11.8
# dtype: float64

# %%
marks.var()
# Out:
# iq       280.0
# marks    170.0
# lpa       10.2
# dtype: float64

# %%
marks.median()
# Out:
# iq       90.0
# marks    70.0
# lpa      14.0
# dtype: float64

# %% [markdown]
# ### Selecting cols from a DataFrame

# %%
#single col
type(df['player_of_match'])
# Out:
# pandas.core.series.Series

# %%
df['city']
# Out:
# 0       Bangalore
# 1      Chandigarh
# 2           Delhi
# 3          Mumbai
# 4         Kolkata
#           ...
# 811         Dubai
# 812         Dubai
# 813     Abu Dhabi
# 814     Abu Dhabi
# 815         Dubai
# Name: city, Length: 816, dtype: object

# %%
#multiple cols
df[['city','venue','player_of_match']]#through fancy indexing by passing a lisr
# Out:
#            city                                       venue player_of_match
# 0     Bangalore                       M Chinnaswamy Stadium     BB McCullum
# 1    Chandigarh  Punjab Cricket Association Stadium, Mohali      MEK Hussey
# 2         Delhi                            Feroz Shah Kotla     MF Maharoof
# 3        Mumbai                            Wankhede Stadium      MV Boucher
# 4       Kolkata                                Eden Gardens       DJ Hussey
# ..          ...                                         ...             ...
# 811       Dubai         Dubai International Cricket Stadium  AB de Villiers
# 812       Dubai         Dubai International Cricket Stadium       JJ Bumrah
# 813   Abu Dhabi                        Sheikh Zayed Stadium   KS Williamson
# 814   Abu Dhabi                        Sheikh Zayed Stadium      MP Stoinis
# 815       Dubai         Dubai International Cricket Stadium        TA Boult
#
# [816 rows x 3 columns]

# %%
df.sample()
# Out:
#           id    city        date player_of_match  \
# 596  1082610  Rajkot  2017-04-18        CH Gayle
#
#                                       venue  neutral_venue          team1  \
# 596  Saurashtra Cricket Association Stadium              0  Gujarat Lions
#
#                            team2    toss_winner toss_decision  \
# 596  Royal Challengers Bangalore  Gujarat Lions         field
#
#                           winner result  result_margin eliminator method  \
# 596  Royal Challengers Bangalore   runs           21.0          N    NaN
#
#     umpire1    umpire2
# 596  S Ravi  VK Sharma

# %%
df[['team1','team2','winner']]
# Out:
#                            team1                        team2  \
# 0    Royal Challengers Bangalore        Kolkata Knight Riders
# 1                Kings XI Punjab          Chennai Super Kings
# 2               Delhi Daredevils             Rajasthan Royals
# 3                 Mumbai Indians  Royal Challengers Bangalore
# 4          Kolkata Knight Riders              Deccan Chargers
# ..                           ...                          ...
# 811  Royal Challengers Bangalore               Mumbai Indians
# 812               Mumbai Indians               Delhi Capitals
# 813  Royal Challengers Bangalore          Sunrisers Hyderabad
# 814               Delhi Capitals          Sunrisers Hyderabad
# 815               Delhi Capitals               Mumbai Indians
#
#                           winner
# 0          Kolkata Knight Riders
# 1            Chennai Super Kings
# 2               Delhi Daredevils
# 3    Royal Challengers Bangalore
# 4          Kolkata Knight Riders
# ...

# %% [markdown]
# ### Other important methods and attributes

# %%
df['player_of_match'].value_counts()
# Out:
# player_of_match
# AB de Villiers    23
# CH Gayle          22
# RG Sharma         18
# DA Warner         17
# MS Dhoni          17
#                   ..
# S Anirudha         1
# M Kartik           1
# R McLaren          1
# RJ Harris          1
# PJ Cummins         1
# Name: count, Length: 233, dtype: int64

# %%
#Toss Decision Plot
df['toss_decision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# how many matches each team has played
(df['team2'].value_counts() + df['team1'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 203
# Royal Challengers Bangalore    195
# Kolkata Knight Riders          192
# Kings XI Punjab                190
# Chennai Super Kings            178
# Delhi Daredevils               161
# Rajasthan Royals               161
# Sunrisers Hyderabad            124
# Deccan Chargers                 75
# Pune Warriors                   46
# Delhi Capitals                  33
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
movies = pd.read_csv('movies.csv')

# %%
movies.shape
# Out:
# (8551, 8)

# %%
movies.head()
# Out:
#    Unnamed: 0      id                        title  \
# 0           0   19404  Dilwale Dulhania Le Jayenge
# 1           1  724089    Gabriel's Inferno Part II
# 2           2     278     The Shawshank Redemption
# 3           3     238                The Godfather
# 4           4  761053   Gabriel's Inferno Part III
#
#                                             overview release_date  popularity  \
# 0  Raj is a rich, carefree, happy-go-lucky second...   1995-10-20      18.433
# 1  Professor Gabriel Emerson finally learns the t...   2020-07-31       8.439
# 2  Framed in the 1940s for the double murder of h...   1994-09-23      65.570
# 3  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14      63.277
# 4  The final part of the film adaption of the ero...   2020-11-19      26.691
#
#    vote_average  vote_count
# 0           8.7        2763
# 1           8.7        1223
# 2           8.7       18637
# 3           8.7       14052
# 4           8.7         773

# %%
movies.sort_values('title')
# Out:
#       Unnamed: 0      id                               title  \
# 1530        1530  614696                              #Alive
# 5183        5183  455656                        #realityhigh
# 3626        3626  252178                                 '71
# 1907        1907   19913                (500) Days of Summer
# 5838        5838    9805  (T)Raumschiff Surprise - Periode 1
# ...          ...     ...                                 ...
# 6805        6805    7451                                 xXx
# 7140        7140   47971          xXx: Return of Xander Cage
# 8296        8296   11679             xXx: State of the Union
# 5257        5257    8388                      ¡Three Amigos!
# 7595        7595    8202                            Æon Flux
#
#                                                overview release_date  \
# 1530  As a grisly virus rampages a city, a lone man ...   2020-06-24
# 5183  When nerdy high schooler Dani finally attracts...   2017-07-17
# ...

# %%
movies.sort_values(['release_date','title'],ascending=[True,False])
# Out:
#       Unnamed: 0      id                         title  \
# 327          327     775            A Trip to the Moon
# 2621        2621    5698       The Great Train Robbery
# 6270        6270     618         The Birth of a Nation
# 349          349     234   The Cabinet of Dr. Caligari
# 121          121   10098                       The Kid
# ...          ...     ...                           ...
# 6515        6515  793723                    Sentinelle
# 3106        3106  484718              Coming 2 America
# 2541        2541  638597                       Yes Day
# 6              6  791373  Zack Snyder's Justice League
# 7              7  399566             Godzilla vs. Kong
#
#                                                overview release_date  \
# 327   Professor Barbenfouillis and five of his colle...   1902-04-17
# 2621  The clerk at the train station is assaulted an...   1903-12-07
# 6270  Two families, abolitionist Northerners the Sto...   1915-02-08
# ...

# %%
marks.sort_index(ascending=False)
# Out:
#     iq  marks  lpa
# 4   80     70   14
# 3   80     70   14
# 2  120    100   14
# 1   90     70    7
# 0  100     80   10

# %%
#set_index(dataframe) -> inplace
movies.set_index('title')
# Out:
#                              Unnamed: 0      id  \
# title
# Dilwale Dulhania Le Jayenge           0   19404
# Gabriel's Inferno Part II             1  724089
# The Shawshank Redemption              2     278
# The Godfather                         3     238
# Gabriel's Inferno Part III            4  761053
# ...                                 ...     ...
# Disaster Movie                     8546   13805
# Battlefield Earth                  8547    5491
# Dragonball Evolution               8548   14164
# House of the Dead                  8549   11059
# Birdemic: Shock and Terror         8550   40016
#
#                                                                       overview  \
# title
# Dilwale Dulhania Le Jayenge  Raj is a rich, carefree, happy-go-lucky second...
# Gabriel's Inferno Part II    Professor Gabriel Emerson finally learns the t...
# The Shawshank Redemption     Framed in the 1940s for the double murder of h...
# ...

# %%
#reset_index(dataframe and series) -> drop parameter
movies.reset_index()
# Out:
#       index  Unnamed: 0      id                        title  \
# 0         0           0   19404  Dilwale Dulhania Le Jayenge
# 1         1           1  724089    Gabriel's Inferno Part II
# 2         2           2     278     The Shawshank Redemption
# 3         3           3     238                The Godfather
# 4         4           4  761053   Gabriel's Inferno Part III
# ...     ...         ...     ...                          ...
# 8546   8546        8546   13805               Disaster Movie
# 8547   8547        8547    5491            Battlefield Earth
# 8548   8548        8548   14164         Dragonball Evolution
# 8549   8549        8549   11059            House of the Dead
# 8550   8550        8550   40016   Birdemic: Shock and Terror
#
#                                                overview release_date  \
# 0     Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# 1     Professor Gabriel Emerson finally learns the t...   2020-07-31
# ...

# %%
#unique(series)
temp = pd.Series([1,1,2,3,3,4,2,3,4,2,25,53,2,np.nan,np.nan,np.nan])
print(temp)
temp.unique()
# Out:
# 0      1.0
# 1      1.0
# 2      2.0
# 3      3.0
# 4      3.0
# 5      4.0
# 6      2.0
# 7      3.0
# 8      4.0
# 9      2.0
# 10    25.0
# 11    53.0
# 12     2.0
# 13     NaN
# 14     NaN
# 15     NaN
# dtype: float64
# array([ 1.,  2.,  3.,  4., 25., 53., nan])

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df['venue'].unique()
# Out:
# array(['M Chinnaswamy Stadium',
#        'Punjab Cricket Association Stadium, Mohali', 'Feroz Shah Kotla',
#        'Wankhede Stadium', 'Eden Gardens', 'Sawai Mansingh Stadium',
#        'Rajiv Gandhi International Stadium, Uppal',
#        'MA Chidambaram Stadium, Chepauk', 'Dr DY Patil Sports Academy',
#        'Newlands', "St George's Park", 'Kingsmead', 'SuperSport Park',
#        'Buffalo Park', 'New Wanderers Stadium', 'De Beers Diamond Oval',
#        'OUTsurance Oval', 'Brabourne Stadium',
#        'Sardar Patel Stadium, Motera', 'Barabati Stadium',
#        'Vidarbha Cricket Association Stadium, Jamtha',
#        'Himachal Pradesh Cricket Association Stadium', 'Nehru Stadium',
#        'Holkar Cricket Stadium',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#        'Subrata Roy Sahara Stadium',
#        'Shaheed Veer Narayan Singh International Stadium',
#        'JSCA International Stadium Complex', 'Sheikh Zayed Stadium',
# ...

# %%
#nunique(series + dataframe) -> does not count missing values
df['venue'].nunique()
# Out:
# 36

# %%
#isnull(series + dataframe)
df['city'][df['city'].isnull()]
# Out:
# 399    NaN
# 402    NaN
# 403    NaN
# 404    NaN
# 406    NaN
# 407    NaN
# 408    NaN
# 409    NaN
# 410    NaN
# 413    NaN
# 414    NaN
# 415    NaN
# 417    NaN
# Name: city, dtype: object

# %%
df['city'][df['city'].notnull()]
# Out:
# 0       Bangalore
# 1      Chandigarh
# 2           Delhi
# 3          Mumbai
# 4         Kolkata
#           ...
# 811         Dubai
# 812         Dubai
# 813     Abu Dhabi
# 814     Abu Dhabi
# 815         Dubai
# Name: city, Length: 803, dtype: object

# %%
#hasnans(series + dataframe)
df['city'].hasnans
# Out:
# True

# %%
#dropna(series + dataframe) ->how parameter ->all and any
df.dropna()
# Out:
#           id           city        date   player_of_match  \
# 40    336022          Delhi  2008-05-17  DPMD Jayawardene
# 43    336025        Kolkata  2008-05-18           M Ntini
# 60    392183      Cape Town  2009-04-19        DL Vettori
# 63    392186         Durban  2009-04-21          CH Gayle
# 89    392214      Centurion  2009-05-07         ML Hayden
# 192   501215          Kochi  2011-04-18       BB McCullum
# 221   501245        Kolkata  2011-05-07     Iqbal Abdulla
# 231   501255      Bangalore  2011-05-14          CH Gayle
# 429   733993          Delhi  2014-05-10          DW Steyn
# 477   829743  Visakhapatnam  2015-04-22         DA Warner
# 508   829807      Hyderabad  2015-05-15           V Kohli
# 538   980943      Hyderabad  2016-04-26          AB Dinda
# 561   980989        Kolkata  2016-05-14         YK Pathan
# 565   980997  Visakhapatnam  2016-05-17          AB Dinda
# 566   980999      Bangalore  2016-05-18           V Kohli
# ...

# %%
df['city'].fillna('unknown')
# Out:
# 0       Bangalore
# 1      Chandigarh
# 2           Delhi
# 3          Mumbai
# 4         Kolkata
#           ...
# 811         Dubai
# 812         Dubai
# 813     Abu Dhabi
# 814     Abu Dhabi
# 815         Dubai
# Name: city, Length: 816, dtype: object

# %%
#drop_duplicates
marks.duplicated().sum()
# Out:
# 1

# %%
marks.drop_duplicates(keep='last')#parameter keep
# Out:
#     iq  marks  lpa
# 0  100     80   10
# 1   90     70    7
# 2  120    100   14
# 4   80     70   14

# %%
#drop -> to delete or drop a column
temp = pd.Series([10,2,3,14,124,36,362,23,75])
temp
# Out:
# 0     10
# 1      2
# 2      3
# 3     14
# 4    124
# 5     36
# 6    362
# 7     23
# 8     75
# dtype: int64

# %%
temp.drop(index=[0,6])
# Out:
# 1      2
# 2      3
# 3     14
# 4    124
# 5     36
# 7     23
# 8     75
# dtype: int64

# %%
#droping columns
movies.drop(columns=['popularity'])
# Out:
#       Unnamed: 0      id                        title  \
# 0              0   19404  Dilwale Dulhania Le Jayenge
# 1              1  724089    Gabriel's Inferno Part II
# 2              2     278     The Shawshank Redemption
# 3              3     238                The Godfather
# 4              4  761053   Gabriel's Inferno Part III
# ...          ...     ...                          ...
# 8546        8546   13805               Disaster Movie
# 8547        8547    5491            Battlefield Earth
# 8548        8548   14164         Dragonball Evolution
# 8549        8549   11059            House of the Dead
# 8550        8550   40016   Birdemic: Shock and Terror
#
#                                                overview release_date  \
# 0     Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# 1     Professor Gabriel Emerson finally learns the t...   2020-07-31
# 2     Framed in the 1940s for the double murder of h...   1994-09-23
# ...

# %%
#droping rows
movies.drop(index=[4,76,968,986,467])
# Out:
#       Unnamed: 0      id                        title  \
# 0              0   19404  Dilwale Dulhania Le Jayenge
# 1              1  724089    Gabriel's Inferno Part II
# 2              2     278     The Shawshank Redemption
# 3              3     238                The Godfather
# 5              5  696374            Gabriel's Inferno
# ...          ...     ...                          ...
# 8546        8546   13805               Disaster Movie
# 8547        8547    5491            Battlefield Earth
# 8548        8548   14164         Dragonball Evolution
# 8549        8549   11059            House of the Dead
# 8550        8550   40016   Birdemic: Shock and Terror
#
#                                                overview release_date  \
# 0     Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# 1     Professor Gabriel Emerson finally learns the t...   2020-07-31
# 2     Framed in the 1940s for the double murder of h...   1994-09-23
# ...

# %%
#apply 
def sigmoid(value):
    return 1/1 + np.exp(-value)

# %%
temp.apply(sigmoid)
# Out:
# 0    1.000045
# 1    1.135335
# 2    1.049787
# 3    1.000001
# 4    1.000000
# 5    1.000000
# 6    1.000000
# 7    1.000000
# 8    1.000000
# dtype: float64
